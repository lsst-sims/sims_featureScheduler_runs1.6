# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from mw_heavy import bulge_footprint, add_mag_clouds

# %%
nside=32
footprints = bulge_footprint(nside=nside)
footprints = add_mag_clouds(footprints)

# %%
hp.mollview(footprints['r'])
np.sum(footprints['g'])
# Out:
# 2876.710000000001

# %%
from rolling_exgal import big_sky_dust

# %%
footprints = big_sky_dust(nside)

# %%
hp.mollview(footprints['r'])
np.sum(footprints['g'])
# Out:
# 2795.4300000000003

# %%
wfd_area = np.where(footprints['r'] == 1)[0].size*hp.nside2pixarea(nside, degrees=True)
wfd_area
# Out:
# 18155.60013320796

# %%
np.sum(footprints['r'])
# Out:
# 6275.07

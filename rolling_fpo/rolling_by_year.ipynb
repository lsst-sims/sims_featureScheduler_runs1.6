# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'rolling_fpo_6nslice1.0_v1.6_10yrs.db'
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
for year in np.arange(0,10):
    sql = 'night > %f and night < %f and note not like "DD%%"' % ((365.25*year+365.25/2), 365.25*(year+1)+365.25/2)
    metric = metrics.CountMetric('filter')
    slicer = slicers.HealpixSlicer()
    summaryStats = [metrics.SumMetric()]
    plotDict = {}
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql,
                                                 plotDict=plotDict,
                                                 summaryMetrics=summaryStats,
                                                runName='fpo'))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database SummaryAllProps with constraint night > 2739.375000 and night < 3104.625000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 201583 visits
# Running:  ['fpo_Count_filter_night_gt_2739_375000_and_night_lt_3104_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 3104.625000 and night < 3469.875000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 204377 visits
# Running:  ['fpo_Count_filter_night_gt_3104_625000_and_night_lt_3469_875000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 913.125000 and night < 1278.375000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 210965 visits
# Running:  ['fpo_Count_filter_night_gt_913_125000_and_night_lt_1278_375000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 222247 visits
# Running:  ['fpo_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 547.875000 and night < 913.125000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 214951 visits
# Running:  ['fpo_Count_filter_night_gt_547_875000_and_night_lt_913_125000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 2008.875000 and night < 2374.125000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 194896 visits
# Running:  ['fpo_Count_filter_night_gt_2008_875000_and_night_lt_2374_125000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 3469.875000 and night < 3835.125000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 138346 visits
# Running:  ['fpo_Count_filter_night_gt_3469_875000_and_night_lt_3835_125000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1643.625000 and night < 2008.875000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 204511 visits
# Running:  ['fpo_Count_filter_night_gt_1643_625000_and_night_lt_2008_875000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 2374.125000 and night < 2739.375000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 214515 visits
# Running:  ['fpo_Count_filter_night_gt_2374_125000_and_night_lt_2739_375000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 182.625000 and night < 547.875000 and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'filter']
# Found 188732 visits
# Running:  ['fpo_Count_filter_night_gt_182_625000_and_night_lt_547_875000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with "night > 2739.375000 and night < 3104.625000 and note not like "DD%"" constraint now.
# monopole: 68.3554  dipole: lon: -42.5593, lat: -69.1512, amp: 26.3393
# Plotting complete.
# Plotting figures with "night > 3104.625000 and night < 3469.875000 and note not like "DD%"" constraint now.
# monopole: 64.457  dipole: lon: 83.9831, lat: -87.6764, amp: 46.3284
# Plotting complete.
# Plotting figures with "night > 913.125000 and night < 1278.375000 and note not like "DD%"" constraint now.
# monopole: 65.1102  dipole: lon: 168.958, lat: -65.7599, amp: 32.0172
# Plotting complete.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# monopole: 67.3776  dipole: lon: 58.8027, lat: -83.4193, amp: 34.808
# Plotting complete.
# Plotting figures with "night > 547.875000 and night < 913.125000 and note not like "DD%"" constraint now.
# monopole: 70.2633  dipole: lon: -155.222, lat: -47.9395, amp: 27.1034
# Plotting complete.
# Plotting figures with "night > 2008.875000 and night < 2374.125000 and note not like "DD%"" constraint now.
# monopole: 61.5182  dipole: lon: 20.3139, lat: -73.4087, amp: 40.5816
# Plotting complete.
# Plotting figures with "night > 3469.875000 and night < 3835.125000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 56.4734  dipole: lon: -92.9478, lat: -3.92803, amp: 40.5981
# Plotting complete.
# Plotting figures with "night > 1643.625000 and night < 2008.875000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 62.4641  dipole: lon: 29.6847, lat: -84.6952, amp: 41.4254
# Plotting complete.
# Plotting figures with "night > 2374.125000 and night < 2739.375000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 73.0552  dipole: lon: -27.4284, lat: -57.2891, amp: 44.0186
# Plotting complete.
# Plotting figures with "night > 182.625000 and night < 547.875000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 58.9433  dipole: lon: -130.949, lat: -87.1199, amp: 24.4422
# Plotting complete.
